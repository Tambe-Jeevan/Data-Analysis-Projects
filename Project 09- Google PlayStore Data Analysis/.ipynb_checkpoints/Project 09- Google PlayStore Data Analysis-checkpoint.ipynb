# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv(r"C:\Users\tambe\OneDrive\Desktop\data analysis\Project 09- Google PlayStore Data Analysis\9. googleplaystore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ## Data Cleaning

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Replacing Rating null values with average rating
x=df['Rating'].mean()

df.replace(np.nan,x,inplace=True)

# %%
df.Rating.isnull().sum()
# Out:
# 0

# %%
df['Current Ver'].value_counts()
# Out:
# Current Ver
# Varies with device    1302
# 1                      834
# 1.1                    272
# 1.2                    184
# 2                      163
#                       ...
# 9.1                      1
# 4.2.2254.129147          1
# 3.1.6.9                  1
# 8.3                      1
# 2.0.148.0                1
# Name: count, Length: 2785, dtype: int64

# %%
df['Android Ver'].value_counts()
# Out:
# Android Ver
# 4.1 and up            2379
# 4.0.3 and up          1451
# 4.0 and up            1337
# Varies with device    1221
# 4.4 and up             894
# 2.3 and up             643
# 5.0 and up             546
# 4.2 and up             387
# 2.3.3 and up           279
# 2.2 and up             239
# 3.0 and up             237
# 4.3 and up             235
# 2.1 and up             133
# 1.6 and up             116
# 6.0 and up              58
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              22
# 1.5 and up              20
# 4.4W and up             11
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.189542336669291        3
# 1.0 and up               2
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 2.2 - 7.1.1              1
# 7.0 - 7.1.1              1
# 5.0 - 6.0                1
# 4.1 - 7.1.1              1
# 5.0 - 7.1.1              1
# ...

# %%
df['Content Rating'].value_counts()
# Out:
# Content Rating
# Everyone             8382
# Teen                 1146
# Mature 17+            447
# Everyone 10+          377
# Adults only 18+         3
# Unrated                 2
# 4.189542336669291       1
# Name: count, dtype: int64

# %%
df['Content Rating'].replace(np.nan,'Everyone',inplace=True)
df['Android Ver'].replace(np.nan,'4.1 and up',inplace=True)
df['Current Ver'].replace(np.nan,'Varies with device',inplace=True)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.shape
# Out:
# (10358, 13)

# %%
df[df['App']=='Life Made WI-Fi Touchscreen Photo Frame']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating     Genres Last Updated  \
# 10472  1,000+     Free    0  Everyone       4.189542  11-Feb-18       1.0.19
#
#       Current Ver Android Ver
# 10472  4.0 and up    4.189542

# %%
df.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                               3.0
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                   4.189542
# Genres                                          11-Feb-18
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                      4.189542
# Name: 10472, dtype: object

# %%
df['Reviews']=df['Reviews'].str.replace('3.0M','3.0')

# %%
df[df['App']=='Life Made WI-Fi Touchscreen Photo Frame']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     3.0
#
#          Size Installs Type     Price Content Rating     Genres Last Updated  \
# 10472  1,000+     Free    0  Everyone       4.189542  11-Feb-18       1.0.19
#
#       Current Ver Android Ver
# 10472  4.0 and up    4.189542

# %%
df['Reviews']=df['Reviews'].astype('float')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
df.drop(10472,inplace=True)

# %%
df.loc[10472]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 10472
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ...

# %%
df.describe(include='all')
# Out:
#            App Category        Rating       Reviews                Size  \
# count    10357    10357  10357.000000  1.035700e+04               10357
# unique    9659       33           NaN           NaN                 461
# top     ROBLOX   FAMILY           NaN           NaN  Varies with device
# freq         9     1943           NaN           NaN                1526
# mean       NaN      NaN      4.188112  4.059046e+05                 NaN
# std        NaN      NaN      0.484020  2.696778e+06                 NaN
# min        NaN      NaN      1.000000  0.000000e+00                 NaN
# 25%        NaN      NaN      4.100000  3.200000e+01                 NaN
# 50%        NaN      NaN      4.200000  1.680000e+03                 NaN
# 75%        NaN      NaN      4.500000  4.641600e+04                 NaN
# max        NaN      NaN      5.000000  7.815831e+07                 NaN
#
#           Installs   Type  Price Content Rating Genres Last Updated  \
# ...

# %%
df['Rating'].mean()
# Out:
# 4.188112341722555

# %%
df.nunique()
# Out:
# App               9659
# Category            33
# Rating              40
# Reviews           6001
# Size               461
# Installs            21
# Type                 3
# Price               92
# Content Rating       6
# Genres             119
# Last Updated      1377
# Current Ver       2784
# Android Ver         34
# dtype: int64

# %%
df.Type.unique()
# Out:
# array(['Free', 'Paid', 4.189542336669291], dtype=object)

# %%
df[df['Type']=='4.189542336669291']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# ## Total numbers of app that contains Astrology in title

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price Content Rating  \
# 0    159.0  19M   10,000+  Free     0       Everyone
# 1    967.0  14M  500,000+  Free     0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver
# 0               Art & Design     7-Jan-18       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18       2.0.0  4.0.3 and up

# %%
df[df['App'].str.contains('Astrology')]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#         Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570   161143.0  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592     2225.0  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840  398307.0  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#       Last Updated         Current Ver         Android Ver
# 1570     25-Jun-18          5.2.4(881)        4.0.3 and up
# 1592     26-Jul-18               4.2.1        4.0.3 and up
# 10840    25-Jul-18  Varies with device  Varies with device

# %%
len(df[df['App'].str.contains('Astrology')])
# Out:
# 3

# %%
df[df['App'].str.contains('Photo')]
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# 11            Name Art Photo Editor - Focus n Filters  ART_AND_DESIGN     4.4
# 12                     Tattoo Name On My Photo Editor  ART_AND_DESIGN     4.2
# ...                                               ...             ...     ...
# 10389                                  Ghost In Photo     PHOTOGRAPHY     3.9
# 10509                  PIP Selfie Camera Photo Editor     PHOTOGRAPHY     4.4
# 10666                      PIP-Camera FN Photo Effect     PHOTOGRAPHY     4.6
# 10707                  Photo Editor Collage Maker Pro     PHOTOGRAPHY     4.5
# 10740                                      PhotoFunia     PHOTOGRAPHY     4.3
#
# ...

# %% [markdown]
# ## App Ratings

# %%
df.Rating.mean()
# Out:
# 4.188112341722555

# %%
# Which category got highest rating
df.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# EDUCATION              4.374535
# EVENTS                 4.362520
# ART_AND_DESIGN         4.350287
# BOOKS_AND_REFERENCE    4.311068
# PERSONALIZATION        4.304856
# PARENTING              4.281590
# GAME                   4.277438
# BEAUTY                 4.260094
# HEALTH_AND_FITNESS     4.251111
# SOCIAL                 4.246513
# SHOPPING               4.245401
# WEATHER                4.239351
# SPORTS                 4.218576
# PRODUCTIVITY           4.199599
# FAMILY                 4.190966
# AUTO_AND_VEHICLES      4.190288
# MEDICAL                4.184293
# PHOTOGRAPHY            4.183266
# LIBRARIES_AND_DEMO     4.181069
# HOUSE_AND_HOME         4.168431
# FOOD_AND_DRINK         4.167837
# COMMUNICATION          4.157604
# COMICS                 4.156318
# NEWS_AND_MAGAZINES     4.140065
# ENTERTAINMENT          4.136036
# FINANCE                4.134862
# BUSINESS               4.134562
# LIFESTYLE              4.113107
# TRAVEL_AND_LOCAL       4.107027
# ...

# %%
df.groupby('App')['Rating'].max().sort_values(ascending=False).head(10)
# Out:
# App
# Unity CF                                          5.0
# Tic Tac CK                                        5.0
# EP Church Annapolis                               5.0
# Pyaar Ek Dhoka                                    5.0
# Bacterial vaginosis Treatment - Sexual disease    5.0
# EP Radio                                          5.0
# ER Assist                                         5.0
# ES Billing System (Offline App)                   5.0
# Prosperity                                        5.0
# Propel BI APP                                     5.0
# Name: Rating, dtype: float64

# %%
# Apps having five star rating
df[df['Rating']==5]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0     15.0
# 612                 American Girls Mobile Numbers     DATING     5.0      5.0
# 615                                  Awake Dating     DATING     5.0      2.0
# 633                         Spine- The dating app     DATING     5.0      5.0
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0      6.0
# ...                                           ...        ...     ...      ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0     14.0
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0     32.0
# 10776                            Monster Ride Pro       GAME     5.0      1.0
# 10820                             Fr. Daoud Lamei     FAMILY     5.0     22.0
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0      4.0
#
# ...

# %%
len(df[df['Rating']==5])
# Out:
# 271

# %%
df.groupby('Genres')['Rating'].mean().sort_values(ascending=False)
# Out:
# Genres
# Comics;Creativity                      4.800000
# Board;Pretend Play                     4.800000
# Health & Fitness;Education             4.700000
# Adventure;Brain Games                  4.600000
# Strategy;Action & Adventure            4.600000
#                                          ...
# Educational;Creativity                 3.960000
# Educational                            3.914803
# Art & Design;Pretend Play              3.900000
# Health & Fitness;Action & Adventure    3.900000
# Parenting;Brain Games                  3.800000
# Name: Rating, Length: 119, dtype: float64

# %%
df['Genres'].nunique()
# Out:
# 119

# %% [markdown]
# ## Reviews

# %%
df['Reviews'].describe()
# Out:
# count    1.035700e+04
# mean     4.059046e+05
# std      2.696778e+06
# min      0.000000e+00
# 25%      3.200000e+01
# 50%      1.680000e+03
# 75%      4.641600e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
df.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# ...

# %%
df.Reviews.sum()
# Out:
# 4203954052.0

# %%
df.Reviews.max()
# Out:
# 78158306.0

# %%
highest_review = df.Reviews.idxmax()
highest_app_reviews = df.loc[highest_review,'App']
highest_app_reviews
# Out:
# 'Facebook'

# %%
df[df['App']=='Facebook']
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
# 3943  Facebook   SOCIAL     4.1  78128208.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social     3-Aug-18
# 3943  1,000,000,000+  Free     0           Teen  Social     3-Aug-18
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device
# 3943  Varies with device  Varies with device

# %%
df[df.Reviews== df.Reviews.max()]
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social     3-Aug-18
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %%
df.groupby('Category')['Reviews'].sum()
# Out:
# Category
# ART_AND_DESIGN         1.714440e+06
# AUTO_AND_VEHICLES      1.163666e+06
# BEAUTY                 3.962400e+05
# BOOKS_AND_REFERENCE    2.187323e+07
# BUSINESS               1.235817e+07
# COMICS                 3.383276e+06
# COMMUNICATION          6.012736e+08
# DATING                 5.545397e+06
# EDUCATION              2.316550e+07
# ENTERTAINMENT          4.757072e+07
# EVENTS                 1.610180e+05
# FAMILY                 3.967720e+08
# FINANCE                1.699989e+07
# FOOD_AND_DRINK         7.671576e+06
# GAME                   1.415537e+09
# HEALTH_AND_FITNESS     3.084519e+07
# HOUSE_AND_HOME         2.794772e+06
# LIBRARIES_AND_DEMO     1.037118e+06
# LIFESTYLE              1.282058e+07
# MAPS_AND_NAVIGATION    3.065925e+07
# MEDICAL                1.396757e+06
# NEWS_AND_MAGAZINES     3.824587e+07
# PARENTING              9.583310e+05
# PERSONALIZATION        7.519316e+07
# PHOTOGRAPHY            2.042974e+08
# PRODUCTIVITY           1.025545e+08
# ...

# %%
df.Reviews.mean()
# Out:
# 405904.6106015255

# %% [markdown]
# ## Total number of free and paid apps

# %%
df.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# ...

# %%
df.Type.unique()
# Out:
# array(['Free', 'Paid', 4.189542336669291], dtype=object)

# %%
df.Type.value_counts()
# Out:
# Type
# Free                 9591
# Paid                  765
# 4.189542336669291       1
# Name: count, dtype: int64

# %%
df[df['Type']==4.189542336669291]
# Out:
#                             App Category    Rating  Reviews  \
# 9148  Command & Conquer: Rivals   FAMILY  4.189542      0.0
#
#                     Size Installs      Type Price Content Rating    Genres  \
# 9148  Varies with device        0  4.189542     0   Everyone 10+  Strategy
#
#      Last Updated         Current Ver         Android Ver
# 9148    28-Jun-18  Varies with device  Varies with device

# %%
df.drop(9148,inplace=True)

# %%
df.Type.value_counts()
# Out:
# Type
# Free    9591
# Paid     765
# Name: count, dtype: int64

# %%
index=df['Reviews'].sort_values(ascending=False).head().index
df.iloc[index]['App'].to_frame()
# Out:
#                               App
# 2901     Samsung SMART CAMERA App
# 4397         Guns'n'Glory Premium
# 369              Android Messages
# 4358              m>notes notepad
# 2966  Cristiano Ronaldo Wallpaper

# %%
# average rating of free and paid apps
df.groupby('Type')['Rating'].mean()
# Out:
# Type
# Free    4.183399
# Paid    4.247203
# Name: Rating, dtype: float64

# %% [markdown]
# ## Top 5 most installed apps

# %%
df.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# ...

# %%
df.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+'], dtype=object)

# %%
df.Installs.dtypes
# Out:
# dtype('O')

# %%
df[df['Installs']=='Free']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
index = df.sort_values(by='Installs',ascending=False).head().index
df.iloc[index]['App'].to_frame()
# Out:
#                               App
# 2119                   Turbo FAST
# 4163         Offroad G-Class 2018
# 2965  Onefootball - Soccer Scores
# 2156                   Chess Free
# 5021                AE Angry Chef

# %%
df[df.Installs== df.Installs.max()]
# Out:
#                                                     App            Category  \
# 342                                     Viber Messenger       COMMUNICATION
# 347                       imo free video calls and chat       COMMUNICATION
# 371               Google Duo - High Quality Video Calls       COMMUNICATION
# 378         UC Browser - Fast Download Private & Secure       COMMUNICATION
# 383                       imo free video calls and chat       COMMUNICATION
# ...                                                 ...                 ...
# 4365                                          MX Player       VIDEO_PLAYERS
# 4566                         SHAREit - Transfer & Share               TOOLS
# 4676                                    Viber Messenger       COMMUNICATION
# 5596                                     Samsung Health  HEALTH_AND_FITNESS
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
#
# ...

# %%
df[df.Installs== df.Installs.min()]
# Out:
#                                                App            Category  \
# 4465  Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION
# 5307                       Ak Parti Yardım Toplama              SOCIAL
# 5486                        AP Series Solution Pro              FAMILY
# 5945                    Ain Arabic Kids Alif Ba ta              FAMILY
# 6692                                 cronometra-br        PRODUCTIVITY
# 7434                                 Pekalongan CJ              SOCIAL
# 8081                                    CX Network            BUSINESS
# 8614                             Sweden Newspapers  NEWS_AND_MAGAZINES
# 8871                        Test Application DT 02      ART_AND_DESIGN
# 9337                      EG | Explore Folegandros    TRAVEL_AND_LOCAL
# 9719                                  EP Cook Book             MEDICAL
# 9905                                   Eu sou Rico             FINANCE
# ...

# %% [markdown]
# ## Price factos

# %%
df.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#     Reviews  Size     Installs  Type Price Content Rating  \
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# ...

# %%
df.Price.dtypes
# Out:
# dtype('O')

# %%
df.Price.unique()
# Out:
# array(['0', '$4.99 ', '$3.99 ', '$6.99 ', '$1.49 ', '$2.99 ', '$7.99 ',
#        '$5.99 ', '$3.49 ', '$1.99 ', '$9.99 ', '$7.49 ', '$0.99 ',
#        '$9.00 ', '$5.49 ', '$10.00 ', '$24.99 ', '$11.99 ', '$79.99 ',
#        '$16.99 ', '$14.99 ', '$1.00 ', '$29.99 ', '$12.99 ', '$2.49 ',
#        '$10.99 ', '$1.50 ', '$19.99 ', '$15.99 ', '$33.99 ', '$74.99 ',
#        '$39.99 ', '$3.95 ', '$4.49 ', '$1.70 ', '$8.99 ', '$2.00 ',
#        '$3.88 ', '$25.99 ', '$399.99 ', '$17.99 ', '$400.00 ', '$3.02 ',
#        '$1.76 ', '$4.84 ', '$4.77 ', '$1.61 ', '$2.50 ', '$1.59 ',
#        '$6.49 ', '$1.29 ', '$5.00 ', '$13.99 ', '$299.99 ', '$379.99 ',
#        '$37.99 ', '$18.99 ', '$389.99 ', '$19.90 ', '$8.49 ', '$1.75 ',
#        '$14.00 ', '$4.85 ', '$46.99 ', '$109.99 ', '$154.99 ', '$3.08 ',
#        '$2.59 ', '$4.80 ', '$1.96 ', '$19.40 ', '$3.90 ', '$4.59 ',
#        '$15.46 ', '$3.04 ', '$4.29 ', '$2.60 ', '$3.28 ', '$4.60 ',
# ...

# %%
df['Price']=df['Price'].str.replace('$','')

# %%
df['Price']=df['Price'].astype('float')
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.Price.unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df.sort_values(by='Price',ascending=False)
# Out:
#                                                  App   Category  Rating  \
# 4367                        I'm Rich - Trump Edition  LIFESTYLE     3.6
# 5356                               I Am Rich Premium    FINANCE     4.1
# 5351                                       I am rich  LIFESTYLE     3.8
# 5358                                      I am Rich!    FINANCE     3.8
# 5362                                   I Am Rich Pro     FAMILY     4.4
# ...                                              ...        ...     ...
# 3911                                    YouTube Kids     FAMILY     4.5
# 3912                             Asphalt 8: Airborne       GAME     4.5
# 3913                                         PAC-MAN       GAME     4.2
# 3914                                Basketball Stars     SPORTS     4.4
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#          Reviews                Size      Installs  Type   Price  \
# ...

# %%
df.Price.max()
# Out:
# 400.0

# %%
df.Price.min()
# Out:
# 0.0

# %%
df.Price.describe()
# Out:
# count    10356.000000
# mean         1.030900
# std         16.279408
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        400.000000
# Name: Price, dtype: float64

# %%
df[df['Price']==df['Price'].max()]
# Out:
#                            App   Category  Rating  Reviews  Size Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0  7.3M  10,000+
#
#       Type  Price Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle     3-May-18       1.0.1
#
#      Android Ver
# 4367  4.1 and up

# %%
df.groupby('Content Rating')['Price'].mean()
# Out:
# Content Rating
# Adults only 18+    0.000000
# Everyone           1.165225
# Everyone 10+       0.390133
# Mature 17+         0.237383
# Teen               0.572670
# Unrated            0.000000
# Name: Price, dtype: float64

# %%
df.groupby('Content Rating')['Price'].sum()
# Out:
# Content Rating
# Adults only 18+       0.00
# Everyone           9766.92
# Everyone 10+        146.69
# Mature 17+          106.11
# Teen                656.28
# Unrated               0.00
# Name: Price, dtype: float64

# %%
df.groupby('Category')['Price'].mean().sort_values(ascending = False)
# Out:
# Category
# FINANCE                8.057861
# LIFESTYLE              6.329410
# MEDICAL                2.501691
# EVENTS                 1.718594
# FAMILY                 1.246560
# PRODUCTIVITY           0.616536
# BOOKS_AND_REFERENCE    0.520739
# BUSINESS               0.410515
# WEATHER                0.395366
# PERSONALIZATION        0.390387
# PHOTOGRAPHY            0.379596
# TOOLS                  0.317023
# SPORTS                 0.284900
# GAME                   0.256289
# COMMUNICATION          0.227158
# TRAVEL_AND_LOCAL       0.210759
# HEALTH_AND_FITNESS     0.210294
# MAPS_AND_NAVIGATION    0.196715
# DATING                 0.160357
# PARENTING              0.159667
# AUTO_AND_VEHICLES      0.158471
# EDUCATION              0.138154
# ART_AND_DESIGN         0.091846
# ENTERTAINMENT          0.071892
# FOOD_AND_DRINK         0.068387
# VIDEO_PLAYERS          0.059771
# SOCIAL                 0.057036
# SHOPPING               0.024464
# NEWS_AND_MAGAZINES     0.015076
# ...

# %% [markdown]
# ## Last Updated

# %%
df.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#     Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159.0   19M      10,000+  Free    0.0       Everyone
# 1     967.0   14M     500,000+  Free    0.0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644.0   25M  50,000,000+  Free    0.0           Teen
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# ...

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
# Out:
# C:\Users\Aayush\AppData\Local\Temp\ipykernel_2244\20324390.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %%
df['Last Updated'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df['Year']= df['Last Updated'].dt.year

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159.0   19M      10,000+  Free    0.0       Everyone
# 1     967.0   14M     500,000+  Free    0.0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644.0   25M  50,000,000+  Free    0.0           Teen
# 4     967.0  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df['Year'].unique()
# Out:
# array([2018, 2017, 2014, 2016, 2015, 2013, 2012, 2011, 2010])

# %%
d1=df[df['Year'] == 2016]
d1
# Out:
#                                   App             Category    Rating  Reviews  \
# 66                   Used Cars Mexico    AUTO_AND_VEHICLES  4.000000    190.0
# 102        Mirror - Zoom & Exposure -               BEAUTY  3.900000  32090.0
# 176                  Free Book Reader  BOOKS_AND_REFERENCE  3.400000   1680.0
# 200                      SuperLivePro             BUSINESS  4.300000  46353.0
# 361                      Xperia Link™        COMMUNICATION  4.100000  45487.0
# ...                               ...                  ...       ...      ...
# 10761          Greek Bible FP (Audio)  BOOKS_AND_REFERENCE  4.189542      5.0
# 10769                     FQ Magazine            LIFESTYLE  4.189542      1.0
# 10818            Gold Quote - Gold.fr              FINANCE  4.189542     96.0
# 10829  Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE  4.600000    603.0
# 10835                        FR Forms             BUSINESS  4.189542      0.0
#
# ...

# %%
d1.groupby('Year')['Content Rating'].value_counts()
# Out:
# Year  Content Rating
# 2016  Everyone          653
#       Teen               86
#       Everyone 10+       27
#       Mature 17+         23
# Name: count, dtype: int64
