# %%
import pandas as pd
import numpy as np
import seaborn as sea
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\tambe\OneDrive\Desktop\data analysis\Project 06- Data Analysis of India Census 2011\6. India Census 2011.csv")
df
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
df.shape
# Out:
# (640, 25)

# %%
pd.set_option('display.max.rows',641)

# %%
pd.set_option('display.max.columns',26)

# %%
df
# Out:
#      District_code                   State_name                 District_name  \
# 0                1            JAMMU AND KASHMIR                       Kupwara
# 1                2            JAMMU AND KASHMIR                        Badgam
# 2                3            JAMMU AND KASHMIR                   Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                        Kargil
# 4                5            JAMMU AND KASHMIR                         Punch
# 5                6            JAMMU AND KASHMIR                       Rajouri
# 6                7            JAMMU AND KASHMIR                        Kathua
# 7                8            JAMMU AND KASHMIR                      Baramula
# 8                9            JAMMU AND KASHMIR                     Bandipore
# 9               10            JAMMU AND KASHMIR                      Srinagar
# 10              11            JAMMU AND KASHMIR                     Ganderbal
# ...

# %%
df.dtypes
# Out:
# District_code            int64
# State_name              object
# District_name           object
# Population               int64
# Male                     int64
# Female                   int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
df.nunique()
# Out:
# District_code           640
# State_name               35
# District_name           634
# Population              640
# Male                    640
# Female                  640
# Literate                640
# Workers                 640
# Male_Workers            640
# Female_Workers          640
# Cultivator_Workers      639
# Agricultural_Workers    640
# Household_Workers       632
# Hindus                  640
# Muslims                 639
# Christians              622
# Sikhs                   565
# Buddhists               511
# Jains                   546
# Secondary_Education     640
# Higher_Education        640
# Graduate_Education      637
# Age_Group_0_29          640
# Age_Group_30_49         640
# Age_Group_50            639
# dtype: int64

# %%
df.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Population              0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# dtype: int64

# %% [markdown]
# ## Population Distribution

# %%
df.groupby('State_name')['Population'].describe()
# Out:
#                              count          mean           std        min  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS    3.0  1.268603e+05  1.023207e+05    36842.0
# ANDHRA PRADESH                23.0  3.677425e+06  8.402523e+05  2344474.0
# ARUNACHAL PRADESH             16.0  8.648294e+04  4.651899e+04     8004.0
# ASSAM                         27.0  1.155762e+06  5.320247e+05   214102.0
# BIHAR                         38.0  2.739459e+06  1.295928e+06   636342.0
# CHANDIGARH                     1.0  1.055450e+06           NaN  1055450.0
# CHHATTISGARH                  18.0  1.419178e+06  1.064158e+06   139820.0
# DADRA AND NAGAR HAVELI         1.0  3.437090e+05           NaN   343709.0
# DAMAN AND DIU                  2.0  1.216235e+05  9.835785e+04    52074.0
# GOA                            2.0  7.292725e+05  1.254909e+05   640537.0
# GUJARAT                       26.0  2.324604e+06  1.581206e+06   228291.0
# ...

# %%
df['Population'].sum()
# total population of India in 2011
# Out:
# 1210854977

# %%
df['Male'].sum()
# total male population
# Out:
# 623270258

# %%
df['Female'].sum()
# total female population
# Out:
# 587584719

# %%
df['Male'].sum() + df['Female'].sum()
# Out:
# 1210854977

# %%
df.head(10)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
# 5              6  JAMMU AND KASHMIR       Rajouri      642415  345351  297064
# 6              7  JAMMU AND KASHMIR        Kathua      616435  326109  290326
# 7              8  JAMMU AND KASHMIR      Baramula     1008039  534733  473306
# 8              9  JAMMU AND KASHMIR     Bandipore      392232  207680  184552
# 9             10  JAMMU AND KASHMIR      Srinagar     1236829  651124  585705
#
#    Literate  Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# ...

# %%
df.groupby('State_name')['Male'].sum().sort_values(ascending=False)

# Uttar Pradesh has highest number of male populaiton
# Out:
# State_name
# UTTAR PRADESH                  104480510
# MAHARASHTRA                     58243056
# BIHAR                           54278157
# WEST BENGAL                     46809027
# ANDHRA PRADESH                  42442146
# MADHYA PRADESH                  37612306
# TAMIL NADU                      36137975
# RAJASTHAN                       35550997
# GUJARAT                         31491260
# KARNATAKA                       30966657
# ORISSA                          21212136
# JHARKHAND                       16930315
# KERALA                          16027412
# ASSAM                           15939443
# PUNJAB                          14639465
# HARYANA                         13494734
# CHHATTISGARH                    12832895
# NCT OF DELHI                     8987326
# JAMMU AND KASHMIR                6640662
# UTTARAKHAND                      5137773
# HIMACHAL PRADESH                 3481873
# TRIPURA                          1874376
# ...

# %%
df.groupby('State_name')['Female'].sum().sort_values(ascending=False)

# Uttar Pradesh has highest number of female population
# Out:
# State_name
# UTTAR PRADESH                  95331831
# MAHARASHTRA                    54131277
# BIHAR                          49821295
# WEST BENGAL                    44467088
# ANDHRA PRADESH                 42138631
# TAMIL NADU                     36009055
# MADHYA PRADESH                 35014503
# RAJASTHAN                      32997440
# KARNATAKA                      30128640
# GUJARAT                        28948432
# ORISSA                         20762082
# KERALA                         17378649
# JHARKHAND                      16057819
# ASSAM                          15266133
# PUNJAB                         13103873
# CHHATTISGARH                   12712303
# HARYANA                        11856728
# NCT OF DELHI                    7800615
# JAMMU AND KASHMIR               5900640
# UTTARAKHAND                     4948519
# HIMACHAL PRADESH                3382729
# TRIPURA                         1799541
# MEGHALAYA                       1475057
# ...

# %%
# total population of each state
total_popu=df.groupby('State_name')['Population'].sum().sort_values(ascending = False)
total_popu

# Uttar Pradesh is the most populated state of India
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
total_popu.plot(figsize=(40,20),fontsize=20,title='Population Distribution by state')
# Out:
# <Axes: title={'center': 'Population Distribution by state'}, xlabel='State_name'>

# %%
population_percentage_by_state = (total_popu /df['Population'].sum())*100
population_percentage_by_state

# Uttar pradesh has 16.5 % of overall populaiton of India
# Out:
# State_name
# UTTAR PRADESH                  16.501757
# MAHARASHTRA                     9.280577
# BIHAR                           8.597186
# WEST BENGAL                     7.538154
# ANDHRA PRADESH                  6.985211
# MADHYA PRADESH                  5.997977
# TAMIL NADU                      5.958354
# RAJASTHAN                       5.661160
# KARNATAKA                       5.045633
# GUJARAT                         4.991489
# ORISSA                          3.466494
# KERALA                          2.758882
# JHARKHAND                       2.724367
# ASSAM                           2.577152
# PUNJAB                          2.291219
# CHHATTISGARH                    2.109683
# HARYANA                         2.093683
# NCT OF DELHI                    1.386453
# JAMMU AND KASHMIR               1.035739
# UTTARAKHAND                     0.832989
# HIMACHAL PRADESH                0.566922
# TRIPURA                         0.303415
# ...

# %% [markdown]
# ## Gender Analysis

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# 0    439654   229064        190899           38165               34680
# 1    335649   214866        162578           52288               55299
# 2     93770    75079         53265           21814               20869
# 3     86236    51873         39839           12034                8266
# 4    261724   161393        117677           43716               54264
#
# ...

# %%
# total number of males by state
total_male_population_by_state = df.groupby('State_name')['Male'].sum()
total_male_population_by_state
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       202871
# ANDHRA PRADESH                  42442146
# ARUNACHAL PRADESH                 713912
# ASSAM                           15939443
# BIHAR                           54278157
# CHANDIGARH                        580663
# CHHATTISGARH                    12832895
# DADRA AND NAGAR HAVELI            193760
# DAMAN AND DIU                     150301
# GOA                               739140
# GUJARAT                         31491260
# HARYANA                         13494734
# HIMACHAL PRADESH                 3481873
# JAMMU AND KASHMIR                6640662
# JHARKHAND                       16930315
# KARNATAKA                       30966657
# KERALA                          16027412
# LAKSHADWEEP                        33123
# MADHYA PRADESH                  37612306
# MAHARASHTRA                     58243056
# MANIPUR                          1438586
# MEGHALAYA                        1491832
# ...

# %%
# total number of females by state
total_Female_population_by_state = df.groupby('State_name')['Female'].sum()
total_Female_population_by_state
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS      177710
# ANDHRA PRADESH                 42138631
# ARUNACHAL PRADESH                669815
# ASSAM                          15266133
# BIHAR                          49821295
# CHANDIGARH                       474787
# CHHATTISGARH                   12712303
# DADRA AND NAGAR HAVELI           149949
# DAMAN AND DIU                     92946
# GOA                              719405
# GUJARAT                        28948432
# HARYANA                        11856728
# HIMACHAL PRADESH                3382729
# JAMMU AND KASHMIR               5900640
# JHARKHAND                      16057819
# KARNATAKA                      30128640
# KERALA                         17378649
# LAKSHADWEEP                       31350
# MADHYA PRADESH                 35014503
# MAHARASHTRA                    54131277
# MANIPUR                         1417208
# MEGHALAYA                       1475057
# MIZORAM                          541867
# ...

# %%
# gender ratio by state
# gender ratio(number of females per 1000 males)
gender_ratio_by_state = (total_Female_population_by_state/total_male_population_by_state)*1000
gender_ratio_by_state.sort_values(ascending =False)

# Kerala and Pondicherry has more number of female compared to male.
# Out:
# State_name
# KERALA                         1084.307872
# PONDICHERRY                    1037.437695
# TAMIL NADU                      996.432562
# ANDHRA PRADESH                  992.848736
# CHHATTISGARH                    990.602900
# MEGHALAYA                       988.755436
# MANIPUR                         985.139575
# ORISSA                          978.783183
# MIZORAM                         975.740944
# GOA                             973.300051
# KARNATAKA                       972.938086
# HIMACHAL PRADESH                971.525670
# UTTARAKHAND                     963.164196
# TRIPURA                         960.074713
# ASSAM                           957.758248
# WEST BENGAL                     949.968219
# JHARKHAND                       948.465460
# LAKSHADWEEP                     946.472240
# ARUNACHAL PRADESH               938.231883
# MADHYA PRADESH                  930.932100
# NAGALAND                        930.907072
# ...

# %%
Literacy_rates=(df.groupby('District_name')['Literate'].sum()/df.groupby('District_name')['Population'].sum())*100
Literacy_rates.sort_values(ascending=False)

# Pathanamthitta district has highest literacy rate with 88.75% followed by Kottayam with 88.62%.
# Out:
# District_name
# Pathanamthitta                  88.737460
# Kottayam                        88.617514
# Mahe                            87.215420
# Alappuzha                       87.076162
# Ernakulam                       86.999952
# Thrissur                        85.817891
# Aizawl                          85.083023
# Kollam                          85.007750
# Kannur                          84.757489
# Kozhikode                       84.743833
# Thiruvananthapuram              84.369819
# Serchhip                        83.890540
# Idukki                          83.230986
# Kanniyakumari                   82.803653
# Mokokchung                      81.950653
# Lakshadweep                     81.511641
# Mumbai                          81.318891
# Chennai                         81.267351
# North Goa                       81.057887
# Mumbai Suburban                 80.960947
# Malappuram                      80.510076
# New Delhi                       80.405482
# ...

# %% [markdown]
# ## Religion Demographics

# %%
df.head(5)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# 0    439654   229064        190899           38165               34680
# 1    335649   214866        162578           52288               55299
# 2     93770    75079         53265           21814               20869
# 3     86236    51873         39839           12034                8266
# 4    261724   161393        117677           43716               54264
#
# ...

# %%
popu_religion=df[['State_name','Population','Hindus','Muslims','Christians','Sikhs','Buddhists','Jains']]
popu_religion
# Out:
#                       State_name  Population   Hindus  Muslims  Christians  \
# 0              JAMMU AND KASHMIR      870354    37128   823286        1700
# 1              JAMMU AND KASHMIR      753745    10110   736054        1489
# 2              JAMMU AND KASHMIR      133487    22882    19057         658
# 3              JAMMU AND KASHMIR      140802    10341   108239         604
# 4              JAMMU AND KASHMIR      476835    32604   431279         958
# 5              JAMMU AND KASHMIR      642415   221880   402879         983
# 6              JAMMU AND KASHMIR      616435   540063    64234        1828
# 7              JAMMU AND KASHMIR     1008039    30621   959185        1497
# 8              JAMMU AND KASHMIR      392232     8439   382006         572
# 9              JAMMU AND KASHMIR     1236829    42540  1177342        2746
# 10             JAMMU AND KASHMIR      297446     5592   290581         406
# ...

# %%
popu_religion.groupby('State_name').describe()
# Out:
#                             Population                                         \
#                                  count          mean           std        min
# State_name
# ANDAMAN AND NICOBAR ISLANDS        3.0  1.268603e+05  1.023207e+05    36842.0
# ANDHRA PRADESH                    23.0  3.677425e+06  8.402523e+05  2344474.0
# ARUNACHAL PRADESH                 16.0  8.648294e+04  4.651899e+04     8004.0
# ASSAM                             27.0  1.155762e+06  5.320247e+05   214102.0
# BIHAR                             38.0  2.739459e+06  1.295928e+06   636342.0
# CHANDIGARH                         1.0  1.055450e+06           NaN  1055450.0
# CHHATTISGARH                      18.0  1.419178e+06  1.064158e+06   139820.0
# DADRA AND NAGAR HAVELI             1.0  3.437090e+05           NaN   343709.0
# DAMAN AND DIU                      2.0  1.216235e+05  9.835785e+04    52074.0
# GOA                                2.0  7.292725e+05  1.254909e+05   640537.0
# ...

# %%
p1=popu_religion[['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains']].sum()
p1
# Out:
# Hindus        966257353
# Muslims       172245158
# Christians     27819588
# Sikhs          20833116
# Buddhists       8442972
# Jains           4451753
# dtype: int64

# %%
p1.plot(kind='bar',title='Population Distribution on Religion',xlabel='Religion',ylabel='Population')
# Out:
# <Axes: title={'center': 'Population Distribution on Religion'}, xlabel='Religion', ylabel='Population'>

# %%
df.groupby('State_name').agg({'Hindus':'sum','Muslims':'sum','Christians':'sum','Sikhs':'sum', 'Buddhists':'sum', 'Jains':'sum'})
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# ARUNACHAL PRADESH               401876     27045      418732      3287
# ASSAM                         19180759  10679345     1165867     20672
# BIHAR                         86078686  17557809      129247     23779
# CHANDIGARH                      852574     51447        8720    138329
# CHHATTISGARH                  23819789    514998      490542     70036
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# DAMAN AND DIU                   220150     19277        2820       172
# GOA                             963877    121564      366130      1473
# GUJARAT                       53533988   5846761      316178     58246
# HARYANA                       22171128   1781342       50353   1243752
# ...

# %% [markdown]
# ## Workforce Analysis

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# 0    439654   229064        190899           38165               34680
# 1    335649   214866        162578           52288               55299
# 2     93770    75079         53265           21814               20869
# 3     86236    51873         39839           12034                8266
# 4    261724   161393        117677           43716               54264
#
# ...

# %%
total_workers_by_state = df.groupby('State_name')['Workers'].sum()
total_workers_by_state
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS      152535
# ANDHRA PRADESH                 39422906
# ARUNACHAL PRADESH                587657
# ASSAM                          11969690
# BIHAR                          34724987
# CHANDIGARH                       404136
# CHHATTISGARH                   12180225
# DADRA AND NAGAR HAVELI           157161
# DAMAN AND DIU                    121271
# GOA                              577248
# GUJARAT                        24767747
# HARYANA                         8916508
# HIMACHAL PRADESH                3559422
# JAMMU AND KASHMIR               4322713
# JHARKHAND                      13098274
# KARNATAKA                      27872597
# KERALA                         11619063
# LAKSHADWEEP                       18753
# MADHYA PRADESH                 31574133
# MAHARASHTRA                    49427878
# MANIPUR                         1304610
# MEGHALAYA                       1185619
# MIZORAM                          486705
# ...

# %%
total_workers_by_district = df.groupby('District_name')['Workers'].sum()
total_workers_by_district
# Out:
# District_name
# Adilabad                        1323667
# Agra                            1389844
# Ahmadabad                       2594952
# Ahmadnagar                      2204590
# Aizawl                           174636
# Ajmer                           1053722
# Akola                            768154
# Alappuzha                        804471
# Aligarh                         1174361
# Alirajpur                        366797
# Allahabad                       2111907
# Almora                           298211
# Alwar                           1708542
# Ambala                           372139
# Ambedkar Nagar                   787398
# Amravati                        1236322
# Amreli                           657139
# Amritsar                         917856
# Anand                            844794
# Anantapur                       2036166
# Anantnag                         389684
# Anjaw                             10501
# Anugul                           526520
# ...

# %%
# number of male workers by state
total_maleworkers_by_state = df.groupby('State_name')['Male_Workers'].sum()
total_maleworkers_by_state
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS      120889
# ANDHRA PRADESH                 24185595
# ARUNACHAL PRADESH                350273
# ASSAM                           8541560
# BIHAR                          25222189
# CHANDIGARH                       328159
# CHHATTISGARH                    7133866
# DADRA AND NAGAR HAVELI           119293
# DAMAN AND DIU                    107434
# GOA                              419536
# GUJARAT                        18000914
# HARYANA                         6806636
# HIMACHAL PRADESH                2043373
# JAMMU AND KASHMIR               3195090
# JHARKHAND                       8424769
# KARNATAKA                      18270116
# KERALA                          8451569
# LAKSHADWEEP                       15318
# MADHYA PRADESH                 20146970
# MAHARASHTRA                    32616875
# MANIPUR                          739408
# MEGHALAYA                        703709
# MIZORAM                          290740
# ...

# %%
# number of female workers by state
total_femaleworkers_by_state = df.groupby('State_name')['Female_Workers'].sum()
total_femaleworkers_by_state.sort_values(ascending = False)
# Out:
# State_name
# MAHARASHTRA                    16811003
# UTTAR PRADESH                  15967953
# ANDHRA PRADESH                 15237311
# RAJASTHAN                      11589179
# TAMIL NADU                     11449703
# MADHYA PRADESH                 11427163
# KARNATAKA                       9602481
# BIHAR                           9502798
# WEST BENGAL                     8040308
# GUJARAT                         6766833
# ORISSA                          5638934
# CHHATTISGARH                    5046359
# JHARKHAND                       4673505
# ASSAM                           3428130
# KERALA                          3167494
# HARYANA                         2109872
# PUNJAB                          1823205
# HIMACHAL PRADESH                1516049
# UTTARAKHAND                     1320354
# JAMMU AND KASHMIR               1127623
# NCT OF DELHI                     825023
# MANIPUR                          565202
# MEGHALAYA                        481910
# ...

# %%
cultivator_workers_by_state = df.groupby('State_name')['Cultivator_Workers'].sum()
agricultural_workers_by_state = df.groupby('State_name')['Agricultural_Workers'].sum()
household_workers_by_state = df.groupby('State_name')['Household_Workers'].sum()

# %%
print(cultivator_workers_by_state)
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       16567
# ANDHRA PRADESH                  6491522
# ARUNACHAL PRADESH                302723
# ASSAM                           4061627
# BIHAR                           7196226
# CHANDIGARH                         2578
# CHHATTISGARH                    4004796
# DADRA AND NAGAR HAVELI            28164
# DAMAN AND DIU                      2316
# GOA                               31354
# GUJARAT                         5447500
# HARYANA                         2480801
# HIMACHAL PRADESH                2062062
# JAMMU AND KASHMIR               1245316
# JHARKHAND                       3814832
# KARNATAKA                       6580649
# KERALA                           670253
# LAKSHADWEEP                           0
# MADHYA PRADESH                  9844439
# MAHARASHTRA                    12569373
# MANIPUR                          574031
# MEGHALAYA                        494675
# MIZORAM                          229603
# ...

# %%
print(agricultural_workers_by_state)
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS        4781
# ANDHRA PRADESH                 16967754
# ARUNACHAL PRADESH                 36171
# ASSAM                           1845346
# BIHAR                          18345649
# CHANDIGARH                         1687
# CHHATTISGARH                    5091882
# DADRA AND NAGAR HAVELI            17799
# DAMAN AND DIU                       772
# GOA                               26760
# GUJARAT                         6839415
# HARYANA                         1528133
# HIMACHAL PRADESH                 175038
# JAMMU AND KASHMIR                547705
# JHARKHAND                       4436052
# KARNATAKA                       7155963
# KERALA                          1322850
# LAKSHADWEEP                           0
# MADHYA PRADESH                 12192267
# MAHARASHTRA                    13486140
# MANIPUR                          134077
# MEGHALAYA                        198364
# MIZORAM                           41787
# ...

# %%
print(household_workers_by_state)
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       3727
# ANDHRA PRADESH                 1439137
# ARUNACHAL PRADESH                 8365
# ASSAM                           491321
# BIHAR                          1411208
# CHANDIGARH                        4799
# CHHATTISGARH                    187631
# DADRA AND NAGAR HAVELI            2195
# DAMAN AND DIU                      684
# GOA                              14708
# GUJARAT                         343999
# HARYANA                         262280
# HIMACHAL PRADESH                 58719
# JAMMU AND KASHMIR               172586
# JHARKHAND                       455162
# KARNATAKA                       913227
# KERALA                          273022
# LAKSHADWEEP                        264
# MADHYA PRADESH                  959259
# MAHARASHTRA                    1225426
# MANIPUR                          91356
# MEGHALAYA                        20488
# MIZORAM                           7852
# NAGALAND                         22838
# ...

# %% [markdown]
# ## Education Levels

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df['Literacy_Rate']= (df['Literate'] / df['Population']) * 100
literacy_rate_by_state = df.groupby('State_name')['Literacy_Rate'].mean()
literacy_rate_by_state
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS    74.389015
# ANDHRA PRADESH                 59.141908
# ARUNACHAL PRADESH              54.340307
# ASSAM                          61.686130
# BIHAR                          50.394974
# CHANDIGARH                     76.312284
# CHHATTISGARH                   56.364191
# DADRA AND NAGAR HAVELI         64.947383
# DAMAN AND DIU                  75.864727
# GOA                            79.748145
# GUJARAT                        66.505975
# HARYANA                        65.431438
# HIMACHAL PRADESH               72.585777
# JAMMU AND KASHMIR              55.024941
# JHARKHAND                      54.014740
# KARNATAKA                      65.199654
# KERALA                         84.135949
# LAKSHADWEEP                    81.511641
# MADHYA PRADESH                 57.560217
# MAHARASHTRA                    71.411058
# MANIPUR                        66.324303
# MEGHALAYA                      58.810274
# ...

# %%
literacy_rate_by_district = (df.groupby('District_name')['Literate'].sum() /  df.groupby('District_name')['Population'].sum()) * 100
literacy_rate_by_district.sort_values(ascending = False)
# Out:
# District_name
# Pathanamthitta                  88.737460
# Kottayam                        88.617514
# Mahe                            87.215420
# Alappuzha                       87.076162
# Ernakulam                       86.999952
# Thrissur                        85.817891
# Aizawl                          85.083023
# Kollam                          85.007750
# Kannur                          84.757489
# Kozhikode                       84.743833
# Thiruvananthapuram              84.369819
# Serchhip                        83.890540
# Idukki                          83.230986
# Kanniyakumari                   82.803653
# Mokokchung                      81.950653
# Lakshadweep                     81.511641
# Mumbai                          81.318891
# Chennai                         81.267351
# North Goa                       81.057887
# Mumbai Suburban                 80.960947
# Malappuram                      80.510076
# New Delhi                       80.405482
# ...

# %%
pd.set_option('display.max.rows',645)

# %%
secondary_education_by_state = df.groupby('State_name')['Secondary_Education'].sum()
higher_education_by_state = df.groupby('State_name')['Higher_Education'].sum()
graduate_education_by_state = df.groupby('State_name')['Graduate_Education'].sum()

# %%
secondary_education_by_state.sort_values(ascending = False)
# Out:
# State_name
# MAHARASHTRA                    17831786
# UTTAR PRADESH                  17311875
# TAMIL NADU                     10557632
# ANDHRA PRADESH                  9266937
# KARNATAKA                       8431196
# KERALA                          7583656
# BIHAR                           7565444
# WEST BENGAL                     7446104
# GUJARAT                         7345431
# MADHYA PRADESH                  5754570
# RAJASTHAN                       4979245
# ORISSA                          4093205
# PUNJAB                          3946146
# HARYANA                         3217040
# JHARKHAND                       2790642
# ASSAM                           2720548
# NCT OF DELHI                    2582915
# CHHATTISGARH                    1853321
# JAMMU AND KASHMIR               1457576
# HIMACHAL PRADESH                1166943
# UTTARAKHAND                     1121015
# MANIPUR                          394644
# TRIPURA                          295040
# ...

# %%
higher_education_by_state.sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  11978183
# MAHARASHTRA                    10618622
# TAMIL NADU                      5628815
# ANDHRA PRADESH                  5481749
# KARNATAKA                       4702161
# BIHAR                           4600511
# WEST BENGAL                     4364896
# MADHYA PRADESH                  4267299
# KERALA                          3808994
# GUJARAT                         3491202
# RAJASTHAN                       3241557
# PUNJAB                          2426383
# HARYANA                         2137786
# NCT OF DELHI                    2134748
# ORISSA                          1829576
# ASSAM                           1749752
# JHARKHAND                       1636646
# CHHATTISGARH                    1562183
# JAMMU AND KASHMIR                863950
# UTTARAKHAND                      859913
# HIMACHAL PRADESH                 776104
# MANIPUR                          276496
# GOA                              152299
# ...

# %%
graduate_education_by_state.sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  9588223
# MAHARASHTRA                    8463507
# TAMIL NADU                     7131256
# ANDHRA PRADESH                 5069999
# WEST BENGAL                    4618160
# KARNATAKA                      4355748
# RAJASTHAN                      3500508
# MADHYA PRADESH                 3476419
# GUJARAT                        3384559
# BIHAR                          3346072
# KERALA                         2992499
# NCT OF DELHI                   2346885
# HARYANA                        1866017
# ORISSA                         1689899
# PUNJAB                         1574711
# JHARKHAND                      1154047
# CHHATTISGARH                   1072482
# ASSAM                          1017971
# UTTARAKHAND                     818020
# JAMMU AND KASHMIR               615858
# HIMACHAL PRADESH                425328
# MANIPUR                         251453
# CHANDIGARH                      174528
# PONDICHERRY                     161376
# ...

# %%
# Calculate the number of individuals in different age groups by state
age_group_0_29_by_state = df.groupby('State_name')['Age_Group_0_29'].sum()
age_group_30_49_by_state = df.groupby('State_name')['Age_Group_30_49'].sum()
age_group_50_by_state = df.groupby('State_name')['Age_Group_50'].sum()

# %%
age_group_0_29_by_state.sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  126507123
# BIHAR                           66930323
# MAHARASHTRA                     61782561
# WEST BENGAL                     50551737
# ANDHRA PRADESH                  45815669
# MADHYA PRADESH                  44264116
# RAJASTHAN                       42814434
# TAMIL NADU                      36336584
# GUJARAT                         34370917
# KARNATAKA                       33676315
# ORISSA                          23359384
# JHARKHAND                       20576647
# ASSAM                           19042032
# KERALA                          15711427
# CHHATTISGARH                    15230475
# PUNJAB                          15143130
# HARYANA                         15006789
# NCT OF DELHI                     9665080
# JAMMU AND KASHMIR                7725207
# UTTARAKHAND                      6033370
# HIMACHAL PRADESH                 3648872
# TRIPURA                          2093146
# ...

# %%
age_group_30_49_by_state.sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  44192083
# MAHARASHTRA                    30272010
# WEST BENGAL                    25343015
# ANDHRA PRADESH                 23148452
# BIHAR                          22949064
# TAMIL NADU                     21429281
# MADHYA PRADESH                 17814066
# KARNATAKA                      16740325
# GUJARAT                        16291242
# RAJASTHAN                      15938006
# ORISSA                         11179683
# KERALA                          9796202
# ASSAM                           8016988
# JHARKHAND                       7766660
# PUNJAB                          7481850
# CHHATTISGARH                    6505399
# HARYANA                         6403218
# NCT OF DELHI                    4762353
# JAMMU AND KASHMIR               3069723
# UTTARAKHAND                     2419886
# HIMACHAL PRADESH                1905011
# TRIPURA                         1010551
# MANIPUR                          737266
# ...

# %%
age_group_50_by_state.sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  27491073
# MAHARASHTRA                    19912066
# WEST BENGAL                    15268912
# ANDHRA PRADESH                 14845225
# TAMIL NADU                     14314360
# BIHAR                          13816563
# KARNATAKA                      10632806
# MADHYA PRADESH                 10465765
# GUJARAT                         9538689
# RAJASTHAN                       9526395
# KERALA                          7863946
# ORISSA                          7315980
# PUNJAB                          5076836
# JHARKHAND                       4528093
# ASSAM                           4127732
# HARYANA                         3909921
# CHHATTISGARH                    3786209
# NCT OF DELHI                    2343806
# JAMMU AND KASHMIR               1731253
# UTTARAKHAND                     1616428
# HIMACHAL PRADESH                1300556
# TRIPURA                          568604
# MANIPUR                          409796
# ...

# %%
df[df['State_name']=='UTTAR PRADESH']
# Out:
#      District_code     State_name                 District_name  Population  \
# 131            132  UTTAR PRADESH                    Saharanpur     3466382
# 132            133  UTTAR PRADESH                 Muzaffarnagar     4143512
# 133            134  UTTAR PRADESH                        Bijnor     3682713
# 134            135  UTTAR PRADESH                     Moradabad     4772006
# 135            136  UTTAR PRADESH                        Rampur     2335819
# 136            137  UTTAR PRADESH           Jyotiba Phule Nagar     1840221
# 137            138  UTTAR PRADESH                        Meerut     3443689
# 138            139  UTTAR PRADESH                       Baghpat     1303048
# 139            140  UTTAR PRADESH                     Ghaziabad     4681645
# 140            141  UTTAR PRADESH           Gautam Buddha Nagar     1648115
# 141            142  UTTAR PRADESH                   Bulandshahr     3499171
# ...
