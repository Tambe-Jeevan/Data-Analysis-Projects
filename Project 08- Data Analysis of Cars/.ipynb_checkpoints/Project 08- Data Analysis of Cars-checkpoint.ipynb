# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
df= pd.read_csv(r"C:\Users\tambe\OneDrive\Desktop\data analysis\Project 08- Data Analysis of Cars\8. Cars Data1.csv")
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ## Exploring Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=432, step=1)

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df.nunique()
# Out:
# Make            38
# Model          425
# Type             6
# Origin           3
# DriveTrain       3
# MSRP           410
# Invoice        425
# EngineSize      43
# Cylinders        7
# Horsepower     110
# MPG_City        28
# MPG_Highway     33
# Weight         348
# Wheelbase       40
# Length          67
# dtype: int64

# %%
df['Type'].unique()
# Out:
# array(['SUV', 'Sedan', 'Sports', 'Wagon', nan, 'Truck', 'Hybrid'],
#       dtype=object)

# %%
df['Origin'].unique()
# Out:
# array(['Asia', 'Europe', nan, 'USA'], dtype=object)

# %%
df['Type'].value_counts()
# Out:
# Type
# Sedan     262
# SUV        60
# Sports     49
# Wagon      30
# Truck      24
# Hybrid      3
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.shape
# Out:
# (432, 15)

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ## 1. Instruction (For Data Cleaning): Find all Null values in the dataset. If there is any null value in any column, then fill it with mean of the column

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
# column names present in column are float datatypes, so their mean can be easily calculated.
column=['EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
       'Weight', 'Wheelbase', 'Length']

for col in column:
    df[col].fillna(df[col].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
# the remaining column are object type, so their null values are removed without calculating any mean or whatever.
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df
# table size reduce to 428 x 15 compared to 432 x 15 previously
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ## Based on value count: Check what are the different types of make are there in our dataset. And, what is the count (occurance) of each Make in the data?

# %%
df['Make'].value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %%
makeplot = df['Make'].value_counts()

# %%
makeplot.plot(title='Number of Brands',xlabel='Brand Name',ylabel='Value count')
# Out:
# <Axes: title={'center': 'Number of Brands'}, xlabel='Brand Name', ylabel='Value count'>

# %% [markdown]
# ## Filtering: Show all the records from Asia or Europe.

# %%
df[(df['Origin']=='Asia') | (df['Origin']=='Europe')]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df[(df['Origin']=='Asia') | (df['Origin']=='Europe')].count()
# Out:
# Make           281
# Model          281
# Type           281
# Origin         281
# DriveTrain     281
# MSRP           281
# Invoice        281
# EngineSize     281
# Cylinders      281
# Horsepower     281
# MPG_City       281
# MPG_Highway    281
# Weight         281
# Wheelbase      281
# Length         281
# dtype: int64

# %%
df[(df['Origin']=='Asia') | (df['Origin']=='Europe')].nunique()
# Out:
# Make            24
# Model          278
# Type             6
# Origin           2
# DriveTrain       3
# MSRP           272
# Invoice        278
# EngineSize      34
# Cylinders        7
# Horsepower      93
# MPG_City        26
# MPG_Highway     31
# Weight         235
# Wheelbase       34
# Length          53
# dtype: int64

# %% [markdown]
# ## Removing unwanted records: Remove all the records (rows) where Weight is above 4000.

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df[df['Weight']>4000]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %%
df1=df[~(df['Weight']>4000)]
df1
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ## Applying function on a column: Increase all the values of 'MPG_City' column by 3.

# %%
df1['MPG_City']
# Out:
# 1      24.0
# 2      22.0
# 3      20.0
# 4      18.0
# 5      18.0
#        ...
# 427    21.0
# 428    20.0
# 429    19.0
# 430    22.0
# 431    20.0
# Name: MPG_City, Length: 325, dtype: float64

# %%
df1['MPG_City']=df1['MPG_City'].apply(lambda x:x+3)
df1
# Out:
# C:\Users\Aayush\AppData\Local\Temp\ipykernel_20992\3076173614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['MPG_City']=df1['MPG_City'].apply(lambda x:x+3)
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# ...

# %%
df1['MPG_City']
# Out:
# 1      27.0
# 2      25.0
# 3      23.0
# 4      21.0
# 5      21.0
#        ...
# 427    24.0
# 428    23.0
# 429    22.0
# 430    25.0
# 431    23.0
# Name: MPG_City, Length: 325, dtype: float64

# %% [markdown]
# ## Price Breakdown

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
# changing data types of MSRP from object to float

#df['MSRP'] = df['MSRP'].str.replace('$','')
#df['MSRP'] = df['MSRP'].str.replace(',','')
df['MSRP'] = df['MSRP'].astype(float)

# %%
# changing data types of Invoices from object to float

#df['Invoice'] = df['Invoice'].str.replace('$','')
#df['Invoice'] = df['Invoice'].str.replace(',','')
df['Invoice'] = df['Invoice'].astype(float)

# %%
df
# updated df
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  36945.0
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755.0
# ..     ...                      ...    ...     ...        ...      ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565.0
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210.0
# 430  Volvo                      V40  Wagon  Europe      Front  26135.0
# 431  Volvo                     XC70  Wagon  Europe        All  35145.0
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.dtypes
# datatype of MSRP and Invoices has changed to float
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP           float64
# Invoice        float64
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df.describe()
# statistical summary of float data
# Out:
#                 MSRP        Invoice  EngineSize   Cylinders  Horsepower  \
# count     428.000000     428.000000  428.000000  428.000000  428.000000
# mean    32774.855140   30014.700935    3.196729    5.807512  215.885514
# std     19431.716674   17642.117750    1.108595    1.554789   71.836032
# min     10280.000000    9875.000000    1.300000    3.000000   73.000000
# 25%     20334.250000   18866.000000    2.375000    4.000000  165.000000
# 50%     27635.000000   25294.500000    3.000000    6.000000  210.000000
# 75%     39205.000000   35710.250000    3.900000    6.000000  255.000000
# max    192465.000000  173560.000000    8.300000   12.000000  500.000000
#
#          MPG_City  MPG_Highway       Weight   Wheelbase      Length
# count  428.000000   428.000000   428.000000  428.000000  428.000000
# mean    20.060748    26.843458  3577.953271  108.154206  186.362150
# std      5.238218     5.741201   758.983215    8.311813   14.357991
# ...

# %%
df['MSRP'].min()
# minimum price from all Car
# Out:
# 10280.0

# %%
df[df['MSRP']==10280]
# Kia has the minimun price for car which is $ 10280.0
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 210  Kia  Rio 4dr manual  Sedan   Asia      Front  10280.0   9875.0
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 210         1.6        4.0       104.0      26.0         33.0  2403.0
#
#      Wheelbase  Length
# 210       95.0   167.0

# %%
df['MSRP'].max()
# The most expensive car is of value 192465
# Out:
# 192465.0

# %%
df[df['MSRP']==192465]
# the most expensive car is Porsche, model 911 GT2 2dr
# Out:
#         Make        Model    Type  Origin DriveTrain      MSRP   Invoice  \
# 338  Porsche  911 GT2 2dr  Sports  Europe       Rear  192465.0  173560.0
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 338         3.6        6.0       477.0      17.0         24.0  3131.0
#
#      Wheelbase  Length
# 338       93.0   175.0

# %%
df['MSRP'].mean()
# Out:
# 32774.85514018692

# %%
df.groupby('Make')['MSRP'].describe().
# grouping on the bais of Make
# statistical describe of Each Make
# Out:
#                count          mean           std      min       25%      50%  \
# Make
# Volvo           12.0  36314.166667   6176.619344  25135.0  34070.00  37645.0
# Volkswagen      15.0  32248.666667  17036.043667  18715.0  21055.00  23955.0
# Toyota          28.0  22524.464286   9022.429699  10760.0  16195.00  22267.5
# Suzuki           8.0  16230.250000   3547.819119  12269.0  14096.00  16032.5
# Subaru          11.0  25501.818182   4088.919339  19945.0  22670.00  25045.0
# Scion            2.0  13565.000000    848.528137  12965.0  13265.00  13565.0
# Saturn           8.0  17234.375000   4220.191632  10995.0  14712.50  16087.5
# Saab             7.0  37640.000000   4548.494256  30860.0  34232.50  39465.0
# Porsche          7.0  83565.000000  50395.535517  43365.0  54515.00  76765.0
# Pontiac         11.0  24156.363636   6775.019222  15495.0  19665.00  22450.0
# Oldsmobile       3.0  23763.333333   4983.087229  18825.0  21250.00  23675.0
# ...

# %%
g=df.groupby('Make')

# %%
for make, origin in g:
    print(make)
    print(origin)
    
# Grouping on the basis of make and origin
# Out:
# Acura
#     Make                    Model    Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura                      MDX     SUV   Asia        All  36945.0  33337.0
# 1  Acura           RSX Type S 2dr   Sedan   Asia      Front  23820.0  21761.0
# 2  Acura                  TSX 4dr   Sedan   Asia      Front  26990.0  24647.0
# 3  Acura                   TL 4dr   Sedan   Asia      Front  33195.0  30299.0
# 4  Acura               3.5 RL 4dr   Sedan   Asia      Front  43755.0  39014.0
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan   Asia      Front  46100.0  41100.0
# 6  Acura   NSX coupe 2dr manual S  Sports   Asia       Rear  89765.0  79978.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# ...

# %%
df[df['Make']=='Toyota']
# it returns all the value that Where Make = Toyota
# Out:
#        Make                       Model    Type Origin DriveTrain     MSRP  \
# 377  Toyota    Prius 4dr (gas/electric)  Hybrid   Asia      Front  20510.0
# 378  Toyota                 Sequoia SR5     SUV   Asia        All  35695.0
# 379  Toyota              4Runner SR5 V6     SUV   Asia      Front  27710.0
# 380  Toyota               Highlander V6     SUV   Asia        All  27930.0
# 381  Toyota                Land Cruiser     SUV   Asia        All  54765.0
# 382  Toyota                        RAV4     SUV   Asia        All  20290.0
# 383  Toyota              Corolla CE 4dr   Sedan   Asia      Front  14085.0
# 384  Toyota               Corolla S 4dr   Sedan   Asia      Front  15030.0
# 385  Toyota              Corolla LE 4dr   Sedan   Asia      Front  15295.0
# 386  Toyota             Echo 2dr manual   Sedan   Asia      Front  10760.0
# 387  Toyota               Echo 2dr auto   Sedan   Asia      Front  11560.0
# ...

# %%
g.get_group('Toyota')
# it group by values where make = 'Toyota'
# Out:
#        Make                       Model    Type Origin DriveTrain     MSRP  \
# 377  Toyota    Prius 4dr (gas/electric)  Hybrid   Asia      Front  20510.0
# 378  Toyota                 Sequoia SR5     SUV   Asia        All  35695.0
# 379  Toyota              4Runner SR5 V6     SUV   Asia      Front  27710.0
# 380  Toyota               Highlander V6     SUV   Asia        All  27930.0
# 381  Toyota                Land Cruiser     SUV   Asia        All  54765.0
# 382  Toyota                        RAV4     SUV   Asia        All  20290.0
# 383  Toyota              Corolla CE 4dr   Sedan   Asia      Front  14085.0
# 384  Toyota               Corolla S 4dr   Sedan   Asia      Front  15030.0
# 385  Toyota              Corolla LE 4dr   Sedan   Asia      Front  15295.0
# 386  Toyota             Echo 2dr manual   Sedan   Asia      Front  10760.0
# 387  Toyota               Echo 2dr auto   Sedan   Asia      Front  11560.0
# ...

# %%
g1=g['MSRP'].mean(numeric_only=True)
g1
# mean value of each Make
# Out:
# Make
# Acura            42938.571429
# Audi             43307.894737
# BMW              43285.250000
# Buick            30537.777778
# Cadillac         50474.375000
# Chevrolet        26587.037037
# Chrysler         27252.000000
# Dodge            26253.846154
# Ford             24015.869565
# GMC              29560.500000
# Honda            21434.705882
# Hummer           49995.000000
# Hyundai          17476.500000
# Infiniti         36070.000000
# Isuzu            26149.000000
# Jaguar           61580.416667
# Jeep             24518.333333
# Kia              15875.909091
# Land Rover       45831.666667
# Lexus            44215.454545
# Lincoln          42875.555556
# MINI             18499.000000
# Mazda            21770.727273
# Mercedes-Benz    60656.807692
# Mercury          27972.777778
# Mitsubishi       23423.615385
# Nissan           24730.941176
# Oldsmobile       23763.333333
# Pontiac          24156.363636
# Porsche          83565.000000
# Saab             37640.000000
# ...

# %%
g1.plot(kind='bar')
# plotting mean value in bar graph
# Out:
# <Axes: xlabel='Make'>

# %%
g1.max()
# max value from bar graph
# Out:
# 83565.0

# %%
g.get_group('Toyota').min()
# find minimum value of Toyoto
# Out:
# Make                   Toyota
# Model          4Runner SR5 V6
# Type                   Hybrid
# Origin                   Asia
# DriveTrain                All
# MSRP                  10760.0
# Invoice               10144.0
# EngineSize                1.5
# Cylinders                 4.0
# Horsepower              108.0
# MPG_City                 13.0
# MPG_Highway              17.0
# Weight                 2035.0
# Wheelbase                93.0
# Length                  153.0
# dtype: object

# %%
g.get_group('Toyota')['MSRP'].max()
# Out:
# 54765.0

# %%
g.get_group('BMW')['MSRP'].describe()
# Out:
# count       20.000000
# mean     43285.250000
# std      12459.756532
# min      28495.000000
# 25%      35095.000000
# 50%      38995.000000
# 75%      49195.000000
# max      73195.000000
# Name: MSRP, dtype: float64
