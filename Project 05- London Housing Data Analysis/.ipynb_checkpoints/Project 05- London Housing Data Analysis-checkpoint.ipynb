# %%
import pandas as pd
import numpy as np
import seaborn as sea
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\tambe\OneDrive\Desktop\data analysis\Project 05- London Housing Data Analysis\5. London Housing Data.csv")
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
df.shape
# Out:
# (13549, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  object
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 635.2+ KB

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
df.groupby('area').describe()
# Out:
#                        average_price                                          \
#                                count           mean            std       min
# area
# barking and dagenham           301.0  159852.930233   76389.010019   50460.0
# barnet                         301.0  304991.089701  141442.767082   90107.0
# bexley                         301.0  189570.737542   85445.862082   63723.0
# brent                          301.0  270291.252492  134175.513211   71307.0
# bromley                        301.0  254160.621262  113033.792288   81124.0
# camden                         301.0  467500.910299  241363.751273  115419.0
# city of london                 301.0  423942.584718  241965.089578   77101.0
# croydon                        301.0  209349.671096   93618.240449   68006.0
# ealing                         301.0  274537.322259  128472.587445   79272.0
# east midlands                  301.0  121649.890365   47485.949241   44506.0
# ...

# %%
df.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
sea.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.nunique()
# Out:
# date               301
# year                26
# area                45
# average_price    13343
# code                45
# houses_sold       3946
# no_of_crimes      2669
# dtype: int64

# %% [markdown]
# ## Convert datatype of 'Date' column to Date-Time format.

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
df.date = pd.to_datetime(df.date)

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# ## Add a new column 'year' in the dataframe which contains years and month.

# %%
df1=df
df1.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df1['Year'] = df.date.dt.year

# %%
df1.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  Year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
df1['month']=df.date.dt.month
df1.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  Year  month
# 0           NaN  1995      1
# 1           NaN  1995      2
# 2           NaN  1995      3
# 3           NaN  1995      4
# 4           NaN  1995      5

# %% [markdown]
# ## Drop year and month column

# %%
df.drop(['Year','month'],axis=1, inplace = True)

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# ## Crime Analysis

# %%
df.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df[df['no_of_crimes']==0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
df.sort_values(by='no_of_crimes',ascending = False).head(10)
# Out:
#            date         area  average_price       code  houses_sold  \
# 9936 2019-12-01  westminster         968404  E09000033          NaN
# 9928 2019-04-01  westminster         992834  E09000033        155.0
# 9927 2019-03-01  westminster         960161  E09000033        185.0
# 9934 2019-10-01  westminster         927864  E09000033        168.0
# 9725 2002-05-01  westminster         331670  E09000033        573.0
# 9932 2019-08-01  westminster         914870  E09000033        156.0
# 9727 2002-07-01  westminster         353874  E09000033        665.0
# 9716 2001-08-01  westminster         309873  E09000033        566.0
# 9931 2019-07-01  westminster         957897  E09000033        168.0
# 9930 2019-06-01  westminster         997393  E09000033        155.0
#
#       no_of_crimes
# 9936        7461.0
# 9928        7227.0
# 9927        7215.0
# 9934        7208.0
# 9725        7076.0
# 9932        7069.0
# 9727        7012.0
# 9716        7002.0
# 9931        6991.0
# ...

# %%
g1=df.groupby('area')['no_of_crimes']

# %%
# maximum number of crime
g1.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %%
g1.min()
# Out:
# area
# barking and dagenham      1217.0
# barnet                    1703.0
# bexley                     860.0
# brent                     1850.0
# bromley                   1441.0
# camden                    2079.0
# city of london               0.0
# croydon                   2031.0
# ealing                    1871.0
# east midlands                NaN
# east of england              NaN
# enfield                   1635.0
# england                      NaN
# greenwich                 1513.0
# hackney                   1870.0
# hammersmith and fulham    1323.0
# haringey                  1536.0
# harrow                     937.0
# havering                  1130.0
# hillingdon                1445.0
# hounslow                  1529.0
# inner london                 NaN
# islington                 1871.0
# kensington and chelsea    1347.0
# kingston upon thames       692.0
# lambeth                   2381.0
# lewisham                  1675.0
# london                       NaN
# ...

# %%
g1.sum()
# total number of crime in each area
# Out:
# area
# barking and dagenham       366234.0
# barnet                     521763.0
# bexley                     297576.0
# brent                      553173.0
# bromley                    462610.0
# camden                     699955.0
# city of london                 47.0
# croydon                    607524.0
# ealing                     597017.0
# east midlands                   0.0
# east of england                 0.0
# enfield                    475844.0
# england                         0.0
# greenwich                  493472.0
# hackney                    589847.0
# hammersmith and fulham     438461.0
# haringey                   551072.0
# harrow                     287761.0
# havering                   350452.0
# hillingdon                 490465.0
# hounslow                   467213.0
# inner london                    0.0
# islington                  576162.0
# kensington and chelsea     419808.0
# kingston upon thames       227120.0
# lambeth                    719454.0
# ...

# %% [markdown]
# ## Price Analysis

# %%
df.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.insert(1,'year',df.date.dt.year)
df.head()
# Out:
#         date  year            area  average_price       code  houses_sold  \
# 0 1995-01-01  1995  city of london          91449  E09000001         17.0
# 1 1995-02-01  1995  city of london          82203  E09000001          7.0
# 2 1995-03-01  1995  city of london          79121  E09000001         14.0
# 3 1995-04-01  1995  city of london          77101  E09000001          7.0
# 4 1995-05-01  1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
group_london=df[df['area']=='city of london']

# %%
df[(df['year']==1995) & (df['area']=='city of london')]
# Out:
#          date  year            area  average_price       code  houses_sold  \
# 0  1995-01-01  1995  city of london          91449  E09000001         17.0
# 1  1995-02-01  1995  city of london          82203  E09000001          7.0
# 2  1995-03-01  1995  city of london          79121  E09000001         14.0
# 3  1995-04-01  1995  city of london          77101  E09000001          7.0
# 4  1995-05-01  1995  city of london          84409  E09000001         10.0
# 5  1995-06-01  1995  city of london          94901  E09000001         17.0
# 6  1995-07-01  1995  city of london         110128  E09000001         13.0
# 7  1995-08-01  1995  city of london         112329  E09000001         14.0
# 8  1995-09-01  1995  city of london         104473  E09000001         17.0
# 9  1995-10-01  1995  city of london         108038  E09000001         14.0
# 10 1995-11-01  1995  city of london         117636  E09000001         11.0
# ...

# %%
group_london.groupby('year').average_price.describe()
# Out:
#       count           mean           std       min        25%       50%  \
# year
# 1995   12.0   99085.000000  16517.181556   77101.0   83857.50   99687.0
# 1996   12.0  105651.166667   8877.439924   93357.0   98587.25  107282.5
# 1997   12.0  117113.416667   7403.328851  107488.0  112974.25  115898.0
# 1998   12.0  148031.916667  11719.720121  124382.0  142813.00  150690.0
# 1999   12.0  171300.083333  12845.851714  149143.0  163914.50  167751.0
# 2000   12.0  218679.000000  52069.326802  173738.0  177514.50  206521.5
# 2001   12.0  250625.583333  55204.393270  189033.0  218967.75  231166.0
# 2002   12.0  269632.250000  28579.220252  227281.0  253555.25  267184.5
# 2003   12.0  270811.333333  20161.125696  243184.0  258398.00  265600.0
# 2004   12.0  301032.833333  21396.933913  269514.0  287449.50  299692.5
# 2005   12.0  311783.666667  19924.691581  282866.0  300855.00  311174.0
# 2006   12.0  338518.583333  24600.140914  304977.0  318715.25  331706.5
# ...

# %%
group_london.groupby('year').average_price.max()
# Out:
# year
# 1995    127232
# 1996    120543
# 1997    131074
# 1998    163403
# 1999    191157
# 2000    321773
# 2001    362204
# 2002    344239
# 2003    305556
# 2004    333075
# 2005    339626
# 2006    377545
# 2007    473887
# 2008    472397
# 2009    411955
# 2010    498241
# 2011    516319
# 2012    573532
# 2013    662700
# 2014    773768
# 2015    783667
# 2016    911827
# 2017    939912
# 2018    811694
# 2019    894680
# 2020    775309
# Name: average_price, dtype: int64

# %%
group_london.groupby('year').average_price.max().plot(kind = 'line',title='Price History',xlabel='Year',ylabel='Max Price Per Year')
# Out:
# <Axes: title={'center': 'Price History'}, xlabel='Year', ylabel='Max Price Per Year'>

# %%
group_london.groupby('year').average_price.mean()
# Out:
# year
# 1995     99085.000000
# 1996    105651.166667
# 1997    117113.416667
# 1998    148031.916667
# 1999    171300.083333
# 2000    218679.000000
# 2001    250625.583333
# 2002    269632.250000
# 2003    270811.333333
# 2004    301032.833333
# 2005    311783.666667
# 2006    338518.583333
# 2007    433838.416667
# 2008    427296.833333
# 2009    383417.833333
# 2010    453662.833333
# 2011    463930.833333
# 2012    525327.500000
# 2013    570008.666667
# 2014    709385.416667
# 2015    760253.166667
# 2016    818315.500000
# 2017    849790.166667
# 2018    784809.000000
# 2019    786983.083333
# 2020    775309.000000
# Name: average_price, dtype: float64

# %%
group_london.groupby('year').average_price.mean().plot(kind = 'line',title='Price History',xlabel='Year',ylabel='Mean Price Per Year')
# Out:
# <Axes: title={'center': 'Price History'}, xlabel='Year', ylabel='Mean Price Per Year'>

# %%
df[df['average_price']<100000]
# Out:
#             date  year            area  average_price       code  houses_sold  \
# 0     1995-01-01  1995  city of london          91449  E09000001         17.0
# 1     1995-02-01  1995  city of london          82203  E09000001          7.0
# 2     1995-03-01  1995  city of london          79121  E09000001         14.0
# 3     1995-04-01  1995  city of london          77101  E09000001          7.0
# 4     1995-05-01  1995  city of london          84409  E09000001         10.0
# ...          ...   ...             ...            ...        ...          ...
# 13330 2001-11-01  2001         england          95083  E92000001     109149.0
# 13331 2001-12-01  2001         england          95992  E92000001      93329.0
# 13332 2002-01-01  2002         england          96215  E92000001      71678.0
# 13333 2002-02-01  2002         england          96676  E92000001      77131.0
# 13334 2002-03-01  2002         england          98962  E92000001     102828.0
#
#        no_of_crimes
# ...

# %%
df[df['average_price']<100000].area.value_counts()
# Out:
# area
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...

# %% [markdown]
# ## Analysis

# %%
df.head()
# Out:
#         date  year            area  average_price       code  houses_sold  \
# 0 1995-01-01  1995  city of london          91449  E09000001         17.0
# 1 1995-02-01  1995  city of london          82203  E09000001          7.0
# 2 1995-03-01  1995  city of london          79121  E09000001         14.0
# 3 1995-04-01  1995  city of london          77101  E09000001          7.0
# 4 1995-05-01  1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.sort_values(by='houses_sold',ascending = False)
# Out:
#             date  year        area  average_price       code  houses_sold  \
# 13336 2002-05-01  2002     england         104458  E92000001     132163.0
# 13362 2004-07-01  2004     england         156730  E92000001     126778.0
# 13338 2002-07-01  2002     england         110001  E92000001     126475.0
# 13339 2002-08-01  2002     england         112832  E92000001     126360.0
# 13327 2001-08-01  2001     england          93331  E92000001     124849.0
# ...          ...   ...         ...            ...        ...          ...
# 12946 2020-01-01  2020  south east         320700  E12000008          NaN
# 13246 2019-12-01  2019  south west         259011  E12000009          NaN
# 13247 2020-01-01  2020  south west         254320  E12000009          NaN
# 13547 2019-12-01  2019     england         250410  E92000001          NaN
# 13548 2020-01-01  2020     england         247355  E92000001          NaN
#
#        no_of_crimes
# 13336           NaN
# 13362           NaN
# ...

# %%
df.duplicated().value_counts()
# no duplicate values
# Out:
# False    13549
# Name: count, dtype: int64
